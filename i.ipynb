# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('cie_see.csv')
df.head()
# Out:
#        Reg No        Name  Sem  CIE  SEE
# 0  511CS18001    ABHISHEK    5  121  204
# 1  511CS18002  AISHWARYA     5  296  440
# 2  511CS18003      AKASH     5  185  308
# 3  511CS18004     AMRUTA     5  306  450
# 4  511CS18005       ANAND    5   94  154

# %%
x=df[['CIE']]
x
# Out:
#     CIE
# 0   121
# 1   296
# 2   185
# 3   306
# 4    94
# 5    99
# 6   194
# 7   222
# 8   377
# 9   155
# 10  193
# 11   30
# 12  200
# 13  228
# 14  100
# 15  150
# 16  138
# 17  103
# 18  180
# 19   66
# 20  340
# 21  118
# 22  390
# 23  105
# 24  280
# 25  192
# 26  245
# 27  276
# 28  104
# 29  200

# %%
y=df[['SEE']]
y
# Out:
#     SEE
# 0   204
# 1   440
# 2   308
# 3   450
# 4   154
# 5   164
# 6   201
# 7   344
# 8   522
# 9   267
# 10  299
# 11   54
# 12  250
# 13  341
# 14  172
# 15  196
# 16  243
# 17  177
# 18  304
# 19  130
# 20  484
# 21  227
# 22  531
# 23  182
# 24  411
# 25  298
# 26  380
# 27  420
# 28  180
# 29  327

# %%
sns.scatterplot(data=df,x=df['CIE'],y=df['SEE'])
# Out:
# <Axes: xlabel='CIE', ylabel='SEE'>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df[['CIE']],df[['SEE']],test_size=0.2,random_state=40)
print('training set:',x_train.shape[0])
print('testing_set:',x_test.shape[0])
# Out:
# training set: 24
# testing_set: 6

# %%
x_train
# Out:
#     CIE
# 20  340
# 3   306
# 29  200
# 21  118
# 11   30
# 4    94
# 8   377
# 17  103
# 26  245
# 22  390
# 0   121
# 9   155
# 10  193
# 23  105
# 28  104
# 12  200
# 1   296
# 18  180
# 25  192
# 24  280
# 5    99
# 7   222
# 27  276
# 6   194

# %%
x_test
# Out:
#     CIE
# 2   185
# 16  138
# 19   66
# 14  100
# 15  150
# 13  228

# %%
y_train
# Out:
#     SEE
# 20  484
# 3   450
# 29  327
# 21  227
# 11   54
# 4   154
# 8   522
# 17  177
# 26  380
# 22  531
# 0   204
# 9   267
# 10  299
# 23  182
# 28  180
# 12  250
# 1   440
# 18  304
# 25  298
# 24  411
# 5   164
# 7   344
# 27  420
# 6   201

# %%
y_test
# Out:
#     SEE
# 2   308
# 16  243
# 19  130
# 14  172
# 15  196
# 13  341

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)

y_pred=lr.predict(x_test)
y_train_pred=lr.predict(x_train)
 
print('\npredictions on training set:')
print(y_train_pred)
print('\n')

print('\npredictions on the testing set:')
print(y_test)
# Out:
# predictions on training set:
# [[484.93074853]
#  [440.46263751]
#  [301.82676198]
#  [194.58014129]
#  [ 79.48620689]
#  [163.19088646]
#  [533.32251641]
#  [174.96185702]
#  [360.6816148 ]
#  [550.32502944]
#  [198.50379815]
#  [242.97190917]
#  [292.67156266]
#  [177.57762826]
#  [176.26974264]
#  [301.82676198]
#  [427.38378133]
#  [275.66904962]
#  [291.36367704]
#  [406.45761144]
#  [169.73031455]
#  [330.60024559]
#  [401.22606897]
#  [293.97944828]]
#
#
#
# predictions on the testing set:
#     SEE
# 2   308
# 16  243
# 19  130
# 14  172
# 15  196
# 13  341

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
mse=mean_squared_error(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)

print('\n')
print('mean_squared_error:',mse)
print('mean_absolute_error:',mae)
print('r2_score:',r2)
# Out:
# mean_squared_error: 469.1326014289248
# mean_absolute_error: 15.90505018345475
# r2_score: 0.9149025835847242

# %%
import numpy as np 
rmse=np.sqrt(mse)
print(rmse)
# Out:
# 21.659469093884198
